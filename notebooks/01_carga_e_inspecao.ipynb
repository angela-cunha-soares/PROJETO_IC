# %% [markdown]
# # 01 · Carga e inspeção
#
# Parser numérico BR, tipagem canônica e schema.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / 'src'))
import matplotlib.pyplot as plt
from projeto_pcj.load import load_semae, faltantes_por_variavel
from projeto_pcj.schema import FEATURES

# %%
df = load_semae()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Ano                    576 non-null    int64
#  1   Mes                    576 non-null    category
#  2   Calc                   576 non-null    category
#  3   COR(ppm Pt Co)         573 non-null    float64
#  4   TURB.(FTU)             573 non-null    float64
#  5   pH                     573 non-null    float64
#  6   ALC.(ppm CaCO3)        546 non-null    float64
#  7   AC.(ppm CaCO3)         546 non-null    float64
#  8   O.C.(ppm O2)           555 non-null    float64
#  9   DBO(ppm O2)            21 non-null     float64
#  10  O.D.(ppm O2)           560 non-null    float64
#  11  Cl-(ppm Cl-)           555 non-null    float64
#  12  DUR.(ppm CaCO3)        555 non-null    float64
#  13  Fe(ppm Fe)             555 non-null    float64
#  14  Mn(mg/l)               555 non-null    float64
#  15  N(ppm N)               63 non-null     float64
#  16  P(ppm P)               54 non-null     float64
#  17  Cond.(uS/cm)           567 non-null    float64
#  18  Amonia(mg/l)           141 non-null    float64
#  19  Surfact.(mg/l)         3 non-null      float64
#  20  Cianobacteria(cel/ml)  534 non-null    float64
#  21  S.T.(mg/l)             3 non-null      float64
#  22  C.T.(NMP/100ml)        225 non-null    float64
#  23  C.F.(NMP/100ml)        461 non-null    float64
#  24  CLOROFILA(ug/l)        531 non-null    float64
#  25  F(ppm F)               468 non-null    float64
# dtypes: category(2), float64(23), int64(1)
# memory usage: 109.8 KB

# %%
df[['Ano','Mes','Calc']+FEATURES[:6]].head(9)
# Out:
#     Ano  Mes  Calc  COR(ppm Pt Co)  TURB.(FTU)   pH  ALC.(ppm CaCO3)  \
# 0  2009  Jan  Mín.           200.0        64.0  7.0             29.0
# 1  2009  Jan  Méd.           432.0       131.0  7.2             34.0
# 2  2009  Jan  Máx.           690.0       241.0  7.4             38.0
# 3  2009  Fev  Mín.           393.0        72.0  6.5             29.0
# 4  2009  Fev  Méd.           868.0       238.0  7.1             31.0
# 5  2009  Fev  Máx.          1110.0       329.0  7.5             36.0
# 6  2009  Mar  Mín.            75.0        20.0  7.4             40.0
# 7  2009  Mar  Méd.           158.0        63.0  7.4             46.0
# 8  2009  Mar  Máx.           320.0       163.0  7.5             51.0
#
#    AC.(ppm CaCO3)  O.C.(ppm O2)
# 0             3.0           6.3
# 1             5.0           6.8
# 2             8.0           7.5
# 3             6.0           5.9
# 4             7.0           7.2
# 5             8.0           8.9
# 6             6.0           6.4
# 7             8.0           7.9
# 8            10.0           8.6

# %%
df.describe().T
# Out:
#                        count           mean            std       min  \
# Ano                    576.0    2016.500000       4.613779  2009.000
# COR(ppm Pt Co)         573.0     149.253054     192.249766     4.000
# TURB.(FTU)             573.0     102.219895     196.520361     1.000
# pH                     573.0       7.317452       0.289820     4.700
# ALC.(ppm CaCO3)        546.0      63.635531      30.854392    16.000
# AC.(ppm CaCO3)         546.0      12.540293      11.721510     0.000
# O.C.(ppm O2)           555.0       9.064685       5.708409     2.300
# DBO(ppm O2)             21.0      16.376190      26.654810     1.600
# O.D.(ppm O2)           560.0       3.245893       1.604717     0.000
# Cl-(ppm Cl-)           555.0      45.261261      30.991355     5.000
# DUR.(ppm CaCO3)        555.0      55.151351      23.830451    10.000
# Fe(ppm Fe)             555.0       2.388901       2.741449     0.090
# Mn(mg/l)               555.0       0.208919       0.208511     0.010
# N(ppm N)                63.0       7.825079       8.299457     2.070
# P(ppm P)                54.0       0.721481       0.456746     0.060
# Cond.(uS/cm)           567.0     325.670194     180.463045    60.000
# Amonia(mg/l)           141.0       3.989362       3.259131     0.000
# Surfact.(mg/l)           3.0       0.129000       0.000000     0.129
# Cianobacteria(cel/ml)  534.0   10527.398876   14958.841172    57.000
# S.T.(mg/l)               3.0     145.000000       0.000000   145.000
# C.T.(NMP/100ml)        225.0  305963.257778  541761.458500     0.000
# C.F.(NMP/100ml)        461.0   23842.603037   53343.402878     0.000
# CLOROFILA(ug/l)        531.0      36.536836      47.753936     0.000
# F(ppm F)               468.0       0.313521       0.201867     0.000
#
#                               25%        50%         75%          max
# Ano                     2012.7500   2016.500    2020.250     2024.000
# COR(ppm Pt Co)            46.0000     74.000     171.000     1650.000
# TURB.(FTU)                 9.0000     21.000      92.000     1200.000
# pH                         7.2000      7.300       7.500        8.100
# ALC.(ppm CaCO3)           44.0000     57.500      75.750      224.000
# AC.(ppm CaCO3)             7.0000     10.000      13.000      120.000
# O.C.(ppm O2)               6.3000      7.800      10.200       84.000
# DBO(ppm O2)                4.6000      6.200       9.800      102.000
# O.D.(ppm O2)               2.1000      3.100       4.300        9.500
# Cl-(ppm Cl-)              30.0000     39.000      51.000      328.000
# DUR.(ppm CaCO3)           40.0000     50.000      64.000      174.000
# Fe(ppm Fe)                 0.8300      1.280       2.825       26.000
# Mn(mg/l)                   0.1100      0.150       0.220        2.360
# N(ppm N)                   3.4500      6.820       8.400       42.700
# P(ppm P)                   0.3000      0.800       0.930        1.620
# Cond.(uS/cm)             202.5000    283.000     403.000     1438.000
# Amonia(mg/l)               1.3500      3.050       6.130       13.000
# Surfact.(mg/l)             0.1290      0.129       0.129        0.129
# Cianobacteria(cel/ml)   2064.0000   4964.000   13364.000   122480.000
# S.T.(mg/l)               145.0000    145.000     145.000      145.000
# C.T.(NMP/100ml)        30000.0000  90000.000  300000.000  3000000.000
# C.F.(NMP/100ml)         2200.0000   5400.000   19000.000   500000.000
# CLOROFILA(ug/l)           12.2800     25.290      47.170      509.640
# F(ppm F)                   0.1975      0.280       0.380        1.520
