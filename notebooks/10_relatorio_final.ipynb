# %% [markdown]
# # 10 · Relatório final
#
# Síntese executiva. O relatório textual é gerado em `reports/relatorio_resultados.md` por `run_evaluate.py`.

# %%
import sys
from pathlib import Path
# Localiza a raiz do projeto (que contém src/projeto_pcj), seja qual for o cwd
# (VSCode roda com cwd=raiz; Jupyter clássico, com cwd=notebooks/).
_p = Path.cwd()
for _cand in [_p, *_p.parents]:
    if (_cand / 'src' / 'projeto_pcj').is_dir():
        sys.path.insert(0, str(_cand / 'src'))
        break
import matplotlib.pyplot as plt
import config
rel = config.REPORTS_DIR / 'relatorio_resultados.md'
print(rel.read_text(encoding='utf-8') if rel.is_file() else 'Rode run_evaluate.py primeiro.')

# %% [markdown]
# ### Figuras
# Ver `reports/figures/` (`eval_*.png`, `missing_*.png`, `outliers_*.png`, `metodos_*.png`).
